# %%
# প্রয়োজনীয় লাইব্রেরি ইমপোর্ট
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. CSV ফাইল লোড
df = pd.read_csv("sales_data.csv")

# %%
# 2. ডেটার প্রথম ৫ লাইন দেখা
print("📌 প্রথম ৫টি রো:")
print(df.head())
# Out:
# 📌 প্রথম ৫টি রো:
#    OrderID        Date     Customer Region    Category   Sales  Quantity
# 0      101  2025-02-10   Jane Smith  North   Groceries  160.20         3
# 1      102  2025-02-17   Jane Smith  North  Home Decor   64.30         2
# 2      103  2025-01-14  Maria Gomez  North     Fashion  372.21         9
# 3      104  2025-01-27  Maria Gomez   West   Groceries  414.24         1
# 4      105  2025-02-18     Ali Khan   West   Groceries  175.04         4

# %%
# 3. Missing Values চেক
print("\n📌 Missing Values:")
print(df.isnull().sum())
# Out:
# 📌 Missing Values:
# OrderID     0
# Date        0
# Customer    0
# Region      0
# Category    0
# Sales       0
# Quantity    0
# dtype: int64

# %%
# 4. Date কলামকে তারিখে কনভার্ট করা
df['Date'] = pd.to_datetime(df['Date'])

# %%
# 5. মোট সেলস এবং কোয়ান্টিটি
total_sales = df['Sales'].sum()
total_quantity = df['Quantity'].sum()
print(f"\n💰 মোট বিক্রি: {total_sales}")
print(f"📦 মোট পণ্যের সংখ্যা: {total_quantity}")
# Out:
# 💰 মোট বিক্রি: 27407.399999999998
# 📦 মোট পণ্যের সংখ্যা: 578

# %%
# 6. Region অনুযায়ী মোট বিক্রি
region_sales = df.groupby('Region')['Sales'].sum().reset_index()
print("\n📌 Region অনুযায়ী মোট বিক্রি:")
print(region_sales)
# Out:
# 📌 Region অনুযায়ী মোট বিক্রি:
#   Region    Sales
# 0   East  5410.19
# 1  North  9558.58
# 2  South  6583.79
# 3   West  5854.84

# %%
# 7. Category অনুযায়ী গড় বিক্রি
category_avg_sales = df.groupby('Category')['Sales'].mean().reset_index()
print("\n📌 Category অনুযায়ী গড় বিক্রি:")
print(category_avg_sales)
# Out:
# 📌 Category অনুযায়ী গড় বিক্রি:
#       Category       Sales
# 0  Electronics  284.187778
# 1      Fashion  295.297931
# 2    Groceries  276.325294
# 3   Home Decor  239.746667

# %%
# 8. Visualization - Region Sales Bar Chart
plt.figure(figsize=(6,4))
sns.barplot(data=region_sales, x='Region', y='Sales', palette='viridis')
plt.title("Region অনুযায়ী মোট বিক্রি")
plt.ylabel("Sales")
plt.xlabel("Region")
plt.show()
# Out:
# /tmp/ipython-input-2872488627.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=region_sales, x='Region', y='Sales', palette='viridis')
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2437 (\N{BENGALI LETTER A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2472 (\N{BENGALI LETTER NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 9. Visualization - Category Pie Chart
plt.figure(figsize=(5,5))
plt.pie(category_avg_sales['Sales'], labels=category_avg_sales['Category'], autopct='%1.1f%%')
plt.title("Category অনুযায়ী গড় বিক্রির হার")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2455 (\N{BENGALI LETTER GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2524 (\N{BENGALI LETTER RRA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2489 (\N{BENGALI LETTER HA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 10. মাস অনুযায়ী বিক্রির ট্রেন্ড
df['Month'] = df['Date'].dt.to_period('M')
monthly_sales = df.groupby('Month')['Sales'].sum().reset_index()

# %%
plt.figure(figsize=(7,4))
# Convert the 'Month' column to string type for plotting
monthly_sales['Month'] = monthly_sales['Month'].astype(str)
sns.lineplot(data=monthly_sales, x='Month', y='Sales', marker='o')
plt.title("মাস অনুযায়ী বিক্রির ট্রেন্ড")
plt.ylabel("Sales")
plt.xlabel("Month")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2478 (\N{BENGALI LETTER MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2494 (\N{BENGALI VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2488 (\N{BENGALI LETTER SA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2437 (\N{BENGALI LETTER A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
